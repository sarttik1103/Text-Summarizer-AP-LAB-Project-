# %%
text = """World War II or the Second World War (1 September 1939 – 2 September 1945) was a global conflict between two coalitions: the Allies and the Axis powers. Nearly all of the world's countries participated, with many nations mobilising all resources in pursuit of total war. Tanks and aircraft played major roles, enabling the strategic bombing of cities and delivery of the first and only nuclear weapons ever used in war. World War II was the deadliest conflict in history, resulting in 70 to 85 million deaths, more than half of which were civilians. Millions died in genocides, including the Holocaust, and by massacres, starvation, and disease. After the Allied victory, Germany, Austria, Japan, and Korea were occupied, and German and Japanese leaders were tried for war crimes.

The causes of World War II included unresolved tensions in the aftermath of World War I and the rises of fascism in Europe and militarism in Japan. Key events preceding the war included Japan's invasion of Manchuria in 1931, the Spanish Civil War, the outbreak of the Second Sino-Japanese War in 1937, and Germany's annexations of Austria and the Sudetenland. World War II is generally considered to have begun on 1 September 1939, when Nazi Germany, under Adolf Hitler, invaded Poland, leading the United Kingdom and France to declare war on Germany. Poland was divided between Germany and the Soviet Union under the Molotov–Ribbentrop Pact. In 1940, the Soviets annexed the Baltic states and parts of Finland and Romania. After the fall of France in June 1940, the war continued mainly between Germany and the British Empire, with fighting in the Balkans, Mediterranean, and Middle East, the aerial Battle of Britain and the Blitz, and naval Battle of the Atlantic. Through campaigns and treaties, Germany gained control of much of continental Europe and formed the Axis alliance with Italy, Japan, and other countries. In June 1941, Germany led an invasion of the Soviet Union, opening the Eastern Front and initially making large territorial gains.

In December 1941, Japan attacked American and British territories in Asia and the Pacific, including at Pearl Harbor in Hawaii, leading the United States to enter the war against Japan and Germany. Japan conquered much of coastal China and Southeast Asia, but its advances in the Pacific were halted in June 1942 at the Battle of Midway. In late 1942, Axis forces were defeated in North Africa and at Stalingrad in the Soviet Union, and in 1943 their continued defeats on the Eastern Front, an Allied invasion of Italy, and Allied offensives in the Pacific forced them into retreat on all fronts. In 1944, the Western Allies invaded France at Normandy as the Soviet Union recaptured its pre-war territory and the U.S. crippled Japan's navy and captured key Pacific islands. The war in Europe concluded with the liberation of German-occupied territories; invasions of Germany by the Western Allies and the Soviet Union, which culminated in the fall of Berlin to Soviet troops; and Germany's unconditional surrender on 8 May 1945. On 6 and 9 August, the U.S. dropped atomic bombs on Hiroshima and Nagasaki in Japan. Faced with an imminent Allied invasion, the prospect of further atomic bombings, and a Soviet declaration of war and invasion of Manchuria, Japan announced its unconditional surrender on 15 August, and signed a surrender document on 2 September 1945.

World War II transformed the political, economic, and social structures of the world, and established the foundation of international relations for the rest of the 20th century and into the 21st century. The United Nations was created to foster international cooperation and prevent future conflicts, with the victorious great powers—China, France, the Soviet Union, the UK, and the U.S.—becoming the permanent members of its security council. The Soviet Union and U.S. emerged as rival global superpowers, setting the stage for the half-century Cold War. In the wake of Europe's devastation, the influence of its great powers waned, triggering the decolonisation of Africa and Asia. Many countries whose industries had been damaged moved towards economic recovery and expansion."""

# %%
len(text)
# Out:
# 4181

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)

# %%
tokens = [token.text.lower() for token in doc
          if not token.is_stop and
          not token.is_punct and
          token.text !='\n']

# %%
tokens
# Out:
# ['world',
#  'war',
#  'ii',
#  'second',
#  'world',
#  'war',
#  '1',
#  'september',
#  '1939',
#  '2',
#  'september',
#  '1945',
#  'global',
#  'conflict',
#  'coalitions',
#  'allies',
#  'axis',
#  'powers',
#  'nearly',
#  'world',
#  'countries',
#  'participated',
#  'nations',
#  'mobilising',
#  'resources',
#  'pursuit',
#  'total',
#  'war',
#  'tanks',
#  'aircraft',
#  'played',
#  'major',
#  'roles',
#  'enabling',
#  'strategic',
#  'bombing',
#  'cities',
#  'delivery',
#  'nuclear',
#  'weapons',
#  'war',
#  'world',
#  'war',
#  'ii',
#  'deadliest',
#  'conflict',
#  'history',
#  'resulting',
#  '70',
#  '85',
#  'million',
#  'deaths',
#  'half',
#  'civilians',
#  'millions',
#  'died',
#  'genocides',
#  'including',
#  'holocaust',
#  'massacres',
#  'starvation',
#  'disease',
#  'allied',
#  'victory',
#  'germany',
#  'austria',
#  'japan',
#  'korea',
#  'occupied',
#  'german',
#  'japanese',
#  'leaders',
#  'tried',
#  'war',
#  'crimes',
#  '\n\n',
#  'causes',
#  'world',
#  'war',
#  'ii',
#  'included',
#  'unresolved',
#  'tensions',
#  'aftermath',
#  'world',
#  'war',
#  'rises',
#  'fascism',
#  'europe',
#  'militarism',
#  'japan',
#  'key',
#  'events',
#  'preceding',
#  'war',
#  'included',
#  'japan',
#  'invasion',
#  'manchuria',
#  '1931',
#  'spanish',
#  'civil',
#  'war',
#  'outbreak',
#  'second',
#  'sino',
#  'japanese',
#  'war',
#  '1937',
#  'germany',
#  'annexations',
#  'austria',
#  'sudetenland',
#  'world',
#  'war',
#  'ii',
#  'generally',
#  'considered',
#  'begun',
#  '1',
#  'september',
#  '1939',
#  'nazi',
#  'germany',
#  'adolf',
#  'hitler',
#  'invaded',
#  'poland',
#  'leading',
#  'united',
#  'kingdom',
#  'france',
#  'declare',
#  'war',
#  'germany',
#  'poland',
#  'divided',
#  'germany',
#  'soviet',
#  'union',
#  'molotov',
#  'ribbentrop',
#  'pact',
#  '1940',
#  'soviets',
#  'annexed',
#  'baltic',
#  'states',
#  'parts',
#  'finland',
#  'romania',
#  'fall',
#  'france',
#  'june',
#  '1940',
#  'war',
#  'continued',
#  'mainly',
#  'germany',
#  'british',
#  'empire',
#  'fighting',
#  'balkans',
#  'mediterranean',
#  'middle',
#  'east',
#  'aerial',
#  'battle',
#  'britain',
#  'blitz',
#  'naval',
#  'battle',
#  'atlantic',
#  'campaigns',
#  'treaties',
#  'germany',
#  'gained',
#  'control',
#  'continental',
#  'europe',
#  'formed',
#  'axis',
#  'alliance',
#  'italy',
#  'japan',
#  'countries',
#  'june',
#  '1941',
#  'germany',
#  'led',
#  'invasion',
#  'soviet',
#  'union',
#  'opening',
#  'eastern',
#  'initially',
#  'making',
#  'large',
#  'territorial',
#  'gains',
#  '\n\n',
#  'december',
#  '1941',
#  'japan',
#  'attacked',
#  'american',
#  'british',
#  'territories',
#  'asia',
#  'pacific',
#  'including',
#  'pearl',
#  'harbor',
#  'hawaii',
#  'leading',
#  'united',
#  'states',
#  'enter',
#  'war',
#  'japan',
#  'germany',
#  'japan',
#  'conquered',
#  'coastal',
#  'china',
#  'southeast',
#  'asia',
#  'advances',
#  'pacific',
#  'halted',
#  'june',
#  '1942',
#  'battle',
#  'midway',
#  'late',
#  '1942',
#  'axis',
#  'forces',
#  'defeated',
#  'north',
#  'africa',
#  'stalingrad',
#  'soviet',
#  'union',
#  '1943',
#  'continued',
#  'defeats',
#  'eastern',
#  'allied',
#  'invasion',
#  'italy',
#  'allied',
#  'offensives',
#  'pacific',
#  'forced',
#  'retreat',
#  'fronts',
#  '1944',
#  'western',
#  'allies',
#  'invaded',
#  'france',
#  'normandy',
#  'soviet',
#  'union',
#  'recaptured',
#  'pre',
#  'war',
#  'territory',
#  'u.s.',
#  'crippled',
#  'japan',
#  'navy',
#  'captured',
#  'key',
#  'pacific',
#  'islands',
#  'war',
#  'europe',
#  'concluded',
#  'liberation',
#  'german',
#  'occupied',
#  'territories',
#  'invasions',
#  'germany',
#  'western',
#  'allies',
#  'soviet',
#  'union',
#  'culminated',
#  'fall',
#  'berlin',
#  'soviet',
#  'troops',
#  'germany',
#  'unconditional',
#  'surrender',
#  '8',
#  '1945',
#  '6',
#  '9',
#  'august',
#  'u.s.',
#  'dropped',
#  'atomic',
#  'bombs',
#  'hiroshima',
#  'nagasaki',
#  'japan',
#  'faced',
#  'imminent',
#  'allied',
#  'invasion',
#  'prospect',
#  'atomic',
#  'bombings',
#  'soviet',
#  'declaration',
#  'war',
#  'invasion',
#  'manchuria',
#  'japan',
#  'announced',
#  'unconditional',
#  'surrender',
#  '15',
#  'august',
#  'signed',
#  'surrender',
#  'document',
#  '2',
#  'september',
#  '1945',
#  '\n\n',
#  'world',
#  'war',
#  'ii',
#  'transformed',
#  'political',
#  'economic',
#  'social',
#  'structures',
#  'world',
#  'established',
#  'foundation',
#  'international',
#  'relations',
#  'rest',
#  '20th',
#  'century',
#  '21st',
#  'century',
#  'united',
#  'nations',
#  'created',
#  'foster',
#  'international',
#  'cooperation',
#  'prevent',
#  'future',
#  'conflicts',
#  'victorious',
#  'great',
#  'powers',
#  'china',
#  'france',
#  'soviet',
#  'union',
#  'uk',
#  'u.s.—becoming',
#  'permanent',
#  'members',
#  'security',
#  'council',
#  'soviet',
#  'union',
#  'u.s.',
#  'emerged',
#  'rival',
#  'global',
#  'superpowers',
#  'setting',
#  'stage',
#  'half',
#  'century',
#  'cold',
#  'war',
#  'wake',
#  'europe',
#  'devastation',
#  'influence',
#  'great',
#  'powers',
#  'waned',
#  'triggering',
#  'decolonisation',
#  'africa',
#  'asia',
#  'countries',
#  'industries',
#  'damaged',
#  'moved',
#  'economic',
#  'recovery',
#  'expansion']

# %%
tokens1=[]
stopwords = list(STOP_WORDS)
allowed_pos = ['ADJ','PROPN','VERB','NOUN']
for token in doc:
    if token.text in stopwords or token.text in punctuation:
        continue
    if token.pos_ in allowed_pos:
        tokens1.append(token.text)

# %%
tokens1
# Out:
# ['World',
#  'War',
#  'II',
#  'Second',
#  'World',
#  'War',
#  'September',
#  'September',
#  'global',
#  'conflict',
#  'coalitions',
#  'Allies',
#  'Axis',
#  'powers',
#  'world',
#  'countries',
#  'participated',
#  'nations',
#  'mobilising',
#  'resources',
#  'pursuit',
#  'total',
#  'war',
#  'Tanks',
#  'aircraft',
#  'played',
#  'major',
#  'roles',
#  'enabling',
#  'strategic',
#  'bombing',
#  'cities',
#  'delivery',
#  'nuclear',
#  'weapons',
#  'war',
#  'World',
#  'War',
#  'II',
#  'deadliest',
#  'conflict',
#  'history',
#  'resulting',
#  'deaths',
#  'civilians',
#  'Millions',
#  'died',
#  'genocides',
#  'including',
#  'Holocaust',
#  'massacres',
#  'starvation',
#  'disease',
#  'Allied',
#  'victory',
#  'Germany',
#  'Austria',
#  'Japan',
#  'Korea',
#  'occupied',
#  'German',
#  'Japanese',
#  'leaders',
#  'tried',
#  'war',
#  'crimes',
#  'causes',
#  'World',
#  'War',
#  'II',
#  'included',
#  'unresolved',
#  'tensions',
#  'aftermath',
#  'World',
#  'War',
#  'I',
#  'rises',
#  'fascism',
#  'Europe',
#  'militarism',
#  'Japan',
#  'Key',
#  'events',
#  'preceding',
#  'war',
#  'included',
#  'Japan',
#  'invasion',
#  'Manchuria',
#  'Spanish',
#  'Civil',
#  'War',
#  'outbreak',
#  'Second',
#  'Sino',
#  'Japanese',
#  'War',
#  'Germany',
#  'annexations',
#  'Austria',
#  'Sudetenland',
#  'World',
#  'War',
#  'II',
#  'considered',
#  'begun',
#  'September',
#  'Nazi',
#  'Germany',
#  'Adolf',
#  'Hitler',
#  'invaded',
#  'Poland',
#  'leading',
#  'United',
#  'Kingdom',
#  'France',
#  'declare',
#  'war',
#  'Germany',
#  'Poland',
#  'divided',
#  'Germany',
#  'Soviet',
#  'Union',
#  'Molotov',
#  'Ribbentrop',
#  'Pact',
#  'Soviets',
#  'annexed',
#  'Baltic',
#  'states',
#  'parts',
#  'Finland',
#  'Romania',
#  'fall',
#  'France',
#  'June',
#  'war',
#  'continued',
#  'Germany',
#  'British',
#  'Empire',
#  'fighting',
#  'Balkans',
#  'Mediterranean',
#  'Middle',
#  'East',
#  'aerial',
#  'Battle',
#  'Britain',
#  'Blitz',
#  'naval',
#  'Battle',
#  'Atlantic',
#  'campaigns',
#  'treaties',
#  'Germany',
#  'gained',
#  'control',
#  'continental',
#  'Europe',
#  'formed',
#  'Axis',
#  'alliance',
#  'Italy',
#  'Japan',
#  'countries',
#  'June',
#  'Germany',
#  'led',
#  'invasion',
#  'Soviet',
#  'Union',
#  'opening',
#  'Eastern',
#  'Front',
#  'making',
#  'large',
#  'territorial',
#  'gains',
#  'December',
#  'Japan',
#  'attacked',
#  'American',
#  'British',
#  'territories',
#  'Asia',
#  'Pacific',
#  'including',
#  'Pearl',
#  'Harbor',
#  'Hawaii',
#  'leading',
#  'United',
#  'States',
#  'enter',
#  'war',
#  'Japan',
#  'Germany',
#  'Japan',
#  'conquered',
#  'coastal',
#  'China',
#  'Southeast',
#  'Asia',
#  'advances',
#  'Pacific',
#  'halted',
#  'June',
#  'Battle',
#  'Midway',
#  'late',
#  'Axis',
#  'forces',
#  'defeated',
#  'North',
#  'Africa',
#  'Stalingrad',
#  'Soviet',
#  'Union',
#  'continued',
#  'defeats',
#  'Eastern',
#  'Front',
#  'Allied',
#  'invasion',
#  'Italy',
#  'Allied',
#  'offensives',
#  'Pacific',
#  'forced',
#  'retreat',
#  'fronts',
#  'Western',
#  'Allies',
#  'invaded',
#  'France',
#  'Normandy',
#  'Soviet',
#  'Union',
#  'recaptured',
#  'pre',
#  'war',
#  'territory',
#  'U.S.',
#  'crippled',
#  'Japan',
#  'navy',
#  'captured',
#  'key',
#  'Pacific',
#  'islands',
#  'war',
#  'Europe',
#  'concluded',
#  'liberation',
#  'German',
#  'occupied',
#  'territories',
#  'invasions',
#  'Germany',
#  'Western',
#  'Allies',
#  'Soviet',
#  'Union',
#  'culminated',
#  'fall',
#  'Berlin',
#  'Soviet',
#  'troops',
#  'Germany',
#  'unconditional',
#  'surrender',
#  'May',
#  'August',
#  'U.S.',
#  'dropped',
#  'atomic',
#  'bombs',
#  'Hiroshima',
#  'Nagasaki',
#  'Japan',
#  'Faced',
#  'imminent',
#  'Allied',
#  'invasion',
#  'prospect',
#  'atomic',
#  'bombings',
#  'Soviet',
#  'declaration',
#  'war',
#  'invasion',
#  'Manchuria',
#  'Japan',
#  'announced',
#  'unconditional',
#  'surrender',
#  'August',
#  'signed',
#  'surrender',
#  'document',
#  'September',
#  'World',
#  'War',
#  'II',
#  'transformed',
#  'political',
#  'economic',
#  'social',
#  'structures',
#  'world',
#  'established',
#  'foundation',
#  'international',
#  'relations',
#  'rest',
#  '20th',
#  'century',
#  '21st',
#  'century',
#  'United',
#  'Nations',
#  'created',
#  'foster',
#  'international',
#  'cooperation',
#  'prevent',
#  'future',
#  'conflicts',
#  'victorious',
#  'great',
#  'powers',
#  'China',
#  'France',
#  'Soviet',
#  'Union',
#  'UK',
#  'U.S.—becoming',
#  'permanent',
#  'members',
#  'security',
#  'council',
#  'Soviet',
#  'Union',
#  'U.S.',
#  'emerged',
#  'rival',
#  'global',
#  'superpowers',
#  'setting',
#  'stage',
#  'half',
#  'century',
#  'Cold',
#  'War',
#  'wake',
#  'Europe',
#  'devastation',
#  'influence',
#  'great',
#  'powers',
#  'waned',
#  'triggering',
#  'decolonisation',
#  'Africa',
#  'Asia',
#  'Many',
#  'countries',
#  'industries',
#  'damaged',
#  'moved',
#  'economic',
#  'recovery',
#  'expansion']

# %%
from collections import Counter

# %%
word_freq = Counter(tokens)

# %%
word_freq
# Out:
# Counter({'world': 9,
#          'war': 20,
#          'ii': 5,
#          'second': 2,
#          '1': 2,
#          'september': 4,
#          '1939': 2,
#          '2': 2,
#          '1945': 3,
#          'global': 2,
#          'conflict': 2,
#          'coalitions': 1,
#          'allies': 3,
#          'axis': 3,
#          'powers': 3,
#          'nearly': 1,
#          'countries': 3,
#          'participated': 1,
#          'nations': 2,
#          'mobilising': 1,
#          'resources': 1,
#          'pursuit': 1,
#          'total': 1,
#          'tanks': 1,
#          'aircraft': 1,
#          'played': 1,
#          'major': 1,
#          'roles': 1,
#          'enabling': 1,
#          'strategic': 1,
#          'bombing': 1,
#          'cities': 1,
#          'delivery': 1,
#          'nuclear': 1,
#          'weapons': 1,
#          'deadliest': 1,
#          'history': 1,
#          'resulting': 1,
#          '70': 1,
#          '85': 1,
#          'million': 1,
#          'deaths': 1,
#          'half': 2,
#          'civilians': 1,
#          'millions': 1,
#          'died': 1,
#          'genocides': 1,
#          'including': 2,
#          'holocaust': 1,
#          'massacres': 1,
#          'starvation': 1,
#          'disease': 1,
#          'allied': 4,
#          'victory': 1,
#          'germany': 11,
#          'austria': 2,
#          'japan': 10,
#          'korea': 1,
#          'occupied': 2,
#          'german': 2,
#          'japanese': 2,
#          'leaders': 1,
#          'tried': 1,
#          'crimes': 1,
#          '\n\n': 3,
#          'causes': 1,
#          'included': 2,
#          'unresolved': 1,
#          'tensions': 1,
#          'aftermath': 1,
#          'rises': 1,
#          'fascism': 1,
#          'europe': 4,
#          'militarism': 1,
#          'key': 2,
#          'events': 1,
#          'preceding': 1,
#          'invasion': 5,
#          'manchuria': 2,
#          '1931': 1,
#          'spanish': 1,
#          'civil': 1,
#          'outbreak': 1,
#          'sino': 1,
#          '1937': 1,
#          'annexations': 1,
#          'sudetenland': 1,
#          'generally': 1,
#          'considered': 1,
#          'begun': 1,
#          'nazi': 1,
#          'adolf': 1,
#          'hitler': 1,
#          'invaded': 2,
#          'poland': 2,
#          'leading': 2,
#          'united': 3,
#          'kingdom': 1,
#          'france': 4,
#          'declare': 1,
#          'divided': 1,
#          'soviet': 9,
#          'union': 7,
#          'molotov': 1,
#          'ribbentrop': 1,
#          'pact': 1,
#          '1940': 2,
#          'soviets': 1,
#          'annexed': 1,
#          'baltic': 1,
#          'states': 2,
#          'parts': 1,
#          'finland': 1,
#          'romania': 1,
#          'fall': 2,
#          'june': 3,
#          'continued': 2,
#          'mainly': 1,
#          'british': 2,
#          'empire': 1,
#          'fighting': 1,
#          'balkans': 1,
#          'mediterranean': 1,
#          'middle': 1,
#          'east': 1,
#          'aerial': 1,
#          'battle': 3,
#          'britain': 1,
#          'blitz': 1,
#          'naval': 1,
#          'atlantic': 1,
#          'campaigns': 1,
#          'treaties': 1,
#          'gained': 1,
#          'control': 1,
#          'continental': 1,
#          'formed': 1,
#          'alliance': 1,
#          'italy': 2,
#          '1941': 2,
#          'led': 1,
#          'opening': 1,
#          'eastern': 2,
#          'initially': 1,
#          'making': 1,
#          'large': 1,
#          'territorial': 1,
#          'gains': 1,
#          'december': 1,
#          'attacked': 1,
#          'american': 1,
#          'territories': 2,
#          'asia': 3,
#          'pacific': 4,
#          'pearl': 1,
#          'harbor': 1,
#          'hawaii': 1,
#          'enter': 1,
#          'conquered': 1,
#          'coastal': 1,
#          'china': 2,
#          'southeast': 1,
#          'advances': 1,
#          'halted': 1,
#          '1942': 2,
#          'midway': 1,
#          'late': 1,
#          'forces': 1,
#          'defeated': 1,
#          'north': 1,
#          'africa': 2,
#          'stalingrad': 1,
#          '1943': 1,
#          'defeats': 1,
#          'offensives': 1,
#          'forced': 1,
#          'retreat': 1,
#          'fronts': 1,
#          '1944': 1,
#          'western': 2,
#          'normandy': 1,
#          'recaptured': 1,
#          'pre': 1,
#          'territory': 1,
#          'u.s.': 3,
#          'crippled': 1,
#          'navy': 1,
#          'captured': 1,
#          'islands': 1,
#          'concluded': 1,
#          'liberation': 1,
#          'invasions': 1,
#          'culminated': 1,
#          'berlin': 1,
#          'troops': 1,
#          'unconditional': 2,
#          'surrender': 3,
#          '8': 1,
#          '6': 1,
#          '9': 1,
#          'august': 2,
#          'dropped': 1,
#          'atomic': 2,
#          'bombs': 1,
#          'hiroshima': 1,
#          'nagasaki': 1,
#          'faced': 1,
#          'imminent': 1,
#          'prospect': 1,
#          'bombings': 1,
#          'declaration': 1,
#          'announced': 1,
#          '15': 1,
#          'signed': 1,
#          'document': 1,
#          'transformed': 1,
#          'political': 1,
#          'economic': 2,
#          'social': 1,
#          'structures': 1,
#          'established': 1,
#          'foundation': 1,
#          'international': 2,
#          'relations': 1,
#          'rest': 1,
#          '20th': 1,
#          'century': 3,
#          '21st': 1,
#          'created': 1,
#          'foster': 1,
#          'cooperation': 1,
#          'prevent': 1,
#          'future': 1,
#          'conflicts': 1,
#          'victorious': 1,
#          'great': 2,
#          'uk': 1,
#          'u.s.—becoming': 1,
#          'permanent': 1,
#          'members': 1,
#          'security': 1,
#          'council': 1,
#          'emerged': 1,
#          'rival': 1,
#          'superpowers': 1,
#          'setting': 1,
#          'stage': 1,
#          'cold': 1,
#          'wake': 1,
#          'devastation': 1,
#          'influence': 1,
#          'waned': 1,
#          'triggering': 1,
#          'decolonisation': 1,
#          'industries': 1,
#          'damaged': 1,
#          'moved': 1,
#          'recovery': 1,
#          'expansion': 1})

# %%
max_freq = max(word_freq.values())

# %%
max_freq
# Out:
# 20

# %%
for word in word_freq.keys():
    word_freq[word] = word_freq[word]/max_freq

# %%
word_freq
# Out:
# Counter({'world': 0.45,
#          'war': 1.0,
#          'ii': 0.25,
#          'second': 0.1,
#          '1': 0.1,
#          'september': 0.2,
#          '1939': 0.1,
#          '2': 0.1,
#          '1945': 0.15,
#          'global': 0.1,
#          'conflict': 0.1,
#          'coalitions': 0.05,
#          'allies': 0.15,
#          'axis': 0.15,
#          'powers': 0.15,
#          'nearly': 0.05,
#          'countries': 0.15,
#          'participated': 0.05,
#          'nations': 0.1,
#          'mobilising': 0.05,
#          'resources': 0.05,
#          'pursuit': 0.05,
#          'total': 0.05,
#          'tanks': 0.05,
#          'aircraft': 0.05,
#          'played': 0.05,
#          'major': 0.05,
#          'roles': 0.05,
#          'enabling': 0.05,
#          'strategic': 0.05,
#          'bombing': 0.05,
#          'cities': 0.05,
#          'delivery': 0.05,
#          'nuclear': 0.05,
#          'weapons': 0.05,
#          'deadliest': 0.05,
#          'history': 0.05,
#          'resulting': 0.05,
#          '70': 0.05,
#          '85': 0.05,
#          'million': 0.05,
#          'deaths': 0.05,
#          'half': 0.1,
#          'civilians': 0.05,
#          'millions': 0.05,
#          'died': 0.05,
#          'genocides': 0.05,
#          'including': 0.1,
#          'holocaust': 0.05,
#          'massacres': 0.05,
#          'starvation': 0.05,
#          'disease': 0.05,
#          'allied': 0.2,
#          'victory': 0.05,
#          'germany': 0.55,
#          'austria': 0.1,
#          'japan': 0.5,
#          'korea': 0.05,
#          'occupied': 0.1,
#          'german': 0.1,
#          'japanese': 0.1,
#          'leaders': 0.05,
#          'tried': 0.05,
#          'crimes': 0.05,
#          '\n\n': 0.15,
#          'causes': 0.05,
#          'included': 0.1,
#          'unresolved': 0.05,
#          'tensions': 0.05,
#          'aftermath': 0.05,
#          'rises': 0.05,
#          'fascism': 0.05,
#          'europe': 0.2,
#          'militarism': 0.05,
#          'key': 0.1,
#          'events': 0.05,
#          'preceding': 0.05,
#          'invasion': 0.25,
#          'manchuria': 0.1,
#          '1931': 0.05,
#          'spanish': 0.05,
#          'civil': 0.05,
#          'outbreak': 0.05,
#          'sino': 0.05,
#          '1937': 0.05,
#          'annexations': 0.05,
#          'sudetenland': 0.05,
#          'generally': 0.05,
#          'considered': 0.05,
#          'begun': 0.05,
#          'nazi': 0.05,
#          'adolf': 0.05,
#          'hitler': 0.05,
#          'invaded': 0.1,
#          'poland': 0.1,
#          'leading': 0.1,
#          'united': 0.15,
#          'kingdom': 0.05,
#          'france': 0.2,
#          'declare': 0.05,
#          'divided': 0.05,
#          'soviet': 0.45,
#          'union': 0.35,
#          'molotov': 0.05,
#          'ribbentrop': 0.05,
#          'pact': 0.05,
#          '1940': 0.1,
#          'soviets': 0.05,
#          'annexed': 0.05,
#          'baltic': 0.05,
#          'states': 0.1,
#          'parts': 0.05,
#          'finland': 0.05,
#          'romania': 0.05,
#          'fall': 0.1,
#          'june': 0.15,
#          'continued': 0.1,
#          'mainly': 0.05,
#          'british': 0.1,
#          'empire': 0.05,
#          'fighting': 0.05,
#          'balkans': 0.05,
#          'mediterranean': 0.05,
#          'middle': 0.05,
#          'east': 0.05,
#          'aerial': 0.05,
#          'battle': 0.15,
#          'britain': 0.05,
#          'blitz': 0.05,
#          'naval': 0.05,
#          'atlantic': 0.05,
#          'campaigns': 0.05,
#          'treaties': 0.05,
#          'gained': 0.05,
#          'control': 0.05,
#          'continental': 0.05,
#          'formed': 0.05,
#          'alliance': 0.05,
#          'italy': 0.1,
#          '1941': 0.1,
#          'led': 0.05,
#          'opening': 0.05,
#          'eastern': 0.1,
#          'initially': 0.05,
#          'making': 0.05,
#          'large': 0.05,
#          'territorial': 0.05,
#          'gains': 0.05,
#          'december': 0.05,
#          'attacked': 0.05,
#          'american': 0.05,
#          'territories': 0.1,
#          'asia': 0.15,
#          'pacific': 0.2,
#          'pearl': 0.05,
#          'harbor': 0.05,
#          'hawaii': 0.05,
#          'enter': 0.05,
#          'conquered': 0.05,
#          'coastal': 0.05,
#          'china': 0.1,
#          'southeast': 0.05,
#          'advances': 0.05,
#          'halted': 0.05,
#          '1942': 0.1,
#          'midway': 0.05,
#          'late': 0.05,
#          'forces': 0.05,
#          'defeated': 0.05,
#          'north': 0.05,
#          'africa': 0.1,
#          'stalingrad': 0.05,
#          '1943': 0.05,
#          'defeats': 0.05,
#          'offensives': 0.05,
#          'forced': 0.05,
#          'retreat': 0.05,
#          'fronts': 0.05,
#          '1944': 0.05,
#          'western': 0.1,
#          'normandy': 0.05,
#          'recaptured': 0.05,
#          'pre': 0.05,
#          'territory': 0.05,
#          'u.s.': 0.15,
#          'crippled': 0.05,
#          'navy': 0.05,
#          'captured': 0.05,
#          'islands': 0.05,
#          'concluded': 0.05,
#          'liberation': 0.05,
#          'invasions': 0.05,
#          'culminated': 0.05,
#          'berlin': 0.05,
#          'troops': 0.05,
#          'unconditional': 0.1,
#          'surrender': 0.15,
#          '8': 0.05,
#          '6': 0.05,
#          '9': 0.05,
#          'august': 0.1,
#          'dropped': 0.05,
#          'atomic': 0.1,
#          'bombs': 0.05,
#          'hiroshima': 0.05,
#          'nagasaki': 0.05,
#          'faced': 0.05,
#          'imminent': 0.05,
#          'prospect': 0.05,
#          'bombings': 0.05,
#          'declaration': 0.05,
#          'announced': 0.05,
#          '15': 0.05,
#          'signed': 0.05,
#          'document': 0.05,
#          'transformed': 0.05,
#          'political': 0.05,
#          'economic': 0.1,
#          'social': 0.05,
#          'structures': 0.05,
#          'established': 0.05,
#          'foundation': 0.05,
#          'international': 0.1,
#          'relations': 0.05,
#          'rest': 0.05,
#          '20th': 0.05,
#          'century': 0.15,
#          '21st': 0.05,
#          'created': 0.05,
#          'foster': 0.05,
#          'cooperation': 0.05,
#          'prevent': 0.05,
#          'future': 0.05,
#          'conflicts': 0.05,
#          'victorious': 0.05,
#          'great': 0.1,
#          'uk': 0.05,
#          'u.s.—becoming': 0.05,
#          'permanent': 0.05,
#          'members': 0.05,
#          'security': 0.05,
#          'council': 0.05,
#          'emerged': 0.05,
#          'rival': 0.05,
#          'superpowers': 0.05,
#          'setting': 0.05,
#          'stage': 0.05,
#          'cold': 0.05,
#          'wake': 0.05,
#          'devastation': 0.05,
#          'influence': 0.05,
#          'waned': 0.05,
#          'triggering': 0.05,
#          'decolonisation': 0.05,
#          'industries': 0.05,
#          'damaged': 0.05,
#          'moved': 0.05,
#          'recovery': 0.05,
#          'expansion': 0.05})

# %%
sent_token = [sent.text for sent in doc.sents]

# %%
sent_token
# Out:
# ['World War II or the Second World War (1 September 1939 – 2 September 1945) was a global conflict between two coalitions: the Allies and the Axis powers.',
#  "Nearly all of the world's countries participated, with many nations mobilising all resources in pursuit of total war.",
#  'Tanks and aircraft played major roles, enabling the strategic bombing of cities and delivery of the first and only nuclear weapons ever used in war.',
#  'World War II was the deadliest conflict in history, resulting in 70 to 85 million deaths, more than half of which were civilians.',
#  'Millions died in genocides, including the Holocaust, and by massacres, starvation, and disease.',
#  'After the Allied victory, Germany, Austria, Japan, and Korea were occupied, and German and Japanese leaders were tried for war crimes.\n\n',
#  'The causes of World War II included unresolved tensions in the aftermath of World War I and the rises of fascism in Europe and militarism in Japan.',
#  "Key events preceding the war included Japan's invasion of Manchuria in 1931, the Spanish Civil War, the outbreak of the Second Sino-Japanese War in 1937, and Germany's annexations of Austria and the Sudetenland.",
#  'World War II is generally considered to have begun on 1 September 1939, when Nazi Germany, under Adolf Hitler, invaded Poland, leading the United Kingdom and France to declare war on Germany.',
#  'Poland was divided between Germany and the Soviet Union under the Molotov–Ribbentrop Pact.',
#  'In 1940, the Soviets annexed the Baltic states and parts of Finland and Romania.',
#  'After the fall of France in June 1940, the war continued mainly between Germany and the British Empire, with fighting in the Balkans, Mediterranean, and Middle East, the aerial Battle of Britain and the Blitz, and naval Battle of the Atlantic.',
#  'Through campaigns and treaties, Germany gained control of much of continental Europe and formed the Axis alliance with Italy, Japan, and other countries.',
#  'In June 1941, Germany led an invasion of the Soviet Union, opening the Eastern Front and initially making large territorial gains.\n\n',
#  'In December 1941, Japan attacked American and British territories in Asia and the Pacific, including at Pearl Harbor in Hawaii, leading the United States to enter the war against Japan and Germany.',
#  'Japan conquered much of coastal China and Southeast Asia, but its advances in the Pacific were halted in June 1942 at the Battle of Midway.',
#  'In late 1942, Axis forces were defeated in North Africa and at Stalingrad in the Soviet Union, and in 1943 their continued defeats on the Eastern Front, an Allied invasion of Italy, and Allied offensives in the Pacific forced them into retreat on all fronts.',
#  "In 1944, the Western Allies invaded France at Normandy as the Soviet Union recaptured its pre-war territory and the U.S. crippled Japan's navy and captured key Pacific islands.",
#  "The war in Europe concluded with the liberation of German-occupied territories; invasions of Germany by the Western Allies and the Soviet Union, which culminated in the fall of Berlin to Soviet troops; and Germany's unconditional surrender on 8 May 1945.",
#  'On 6 and 9 August, the U.S. dropped atomic bombs on Hiroshima and Nagasaki in Japan.',
#  'Faced with an imminent Allied invasion, the prospect of further atomic bombings, and a Soviet declaration of war and invasion of Manchuria, Japan announced its unconditional surrender on 15 August, and signed a surrender document on 2 September 1945.\n\n',
#  'World War II transformed the political, economic, and social structures of the world, and established the foundation of international relations for the rest of the 20th century and into the 21st century.',
#  'The United Nations was created to foster international cooperation and prevent future conflicts, with the victorious great powers—China, France, the Soviet Union, the UK, and the U.S.—becoming the permanent members of its security council.',
#  'The Soviet Union and U.S. emerged as rival global superpowers, setting the stage for the half-century Cold War.',
#  "In the wake of Europe's devastation, the influence of its great powers waned, triggering the decolonisation of Africa and Asia.",
#  'Many countries whose industries had been damaged moved towards economic recovery and expansion.']

# %%
sent_score = {}
for sent in sent_token:
    for word in sent.split():
        if word.lower() in word_freq.keys():
            if sent not in sent_score.keys():
                sent_score[sent] = word_freq[word]
            else:
                sent_score[sent] +=word_freq[word]
        print(word)
# Out:
# World
# War
# II
# or
# the
# Second
# World
# War
# (1
# September
# 1939
# –
# 2
# September
# 1945)
# was
# a
# global
# conflict
# between
# two
# coalitions:
# the
# Allies
# and
# the
# Axis
# powers.
# Nearly
# all
# of
# the
# world's
# countries
# participated,
# with
# many
# nations
# mobilising
# all
# resources
# in
# pursuit
# of
# total
# war.
# Tanks
# and
# aircraft
# played
# major
# roles,
# enabling
# the
# strategic
# bombing
# of
# cities
# and
# delivery
# of
# the
# first
# and
# only
# nuclear
# weapons
# ever
# used
# in
# war.
# World
# War
# II
# was
# the
# deadliest
# conflict
# in
# history,
# resulting
# in
# 70
# to
# 85
# million
# deaths,
# more
# than
# half
# of
# which
# were
# civilians.
# Millions
# died
# in
# genocides,
# including
# the
# Holocaust,
# and
# by
# massacres,
# starvation,
# and
# disease.
# After
# the
# Allied
# victory,
# Germany,
# Austria,
# Japan,
# and
# Korea
# were
# occupied,
# and
# German
# and
# Japanese
# leaders
# were
# tried
# for
# war
# crimes.
# The
# causes
# of
# World
# War
# II
# included
# unresolved
# tensions
# in
# the
# aftermath
# of
# World
# War
# I
# and
# the
# rises
# of
# fascism
# in
# Europe
# and
# militarism
# in
# Japan.
# Key
# events
# preceding
# the
# war
# included
# Japan's
# invasion
# of
# Manchuria
# in
# 1931,
# the
# Spanish
# Civil
# War,
# the
# outbreak
# of
# the
# Second
# Sino-Japanese
# War
# in
# 1937,
# and
# Germany's
# annexations
# of
# Austria
# and
# the
# Sudetenland.
# World
# War
# II
# is
# generally
# considered
# to
# have
# begun
# on
# 1
# September
# 1939,
# when
# Nazi
# Germany,
# under
# Adolf
# Hitler,
# invaded
# Poland,
# leading
# the
# United
# Kingdom
# and
# France
# to
# declare
# war
# on
# Germany.
# Poland
# was
# divided
# between
# Germany
# and
# the
# Soviet
# Union
# under
# the
# Molotov–Ribbentrop
# Pact.
# In
# 1940,
# the
# Soviets
# annexed
# the
# Baltic
# states
# and
# parts
# of
# Finland
# and
# Romania.
# After
# the
# fall
# of
# France
# in
# June
# 1940,
# the
# war
# continued
# mainly
# between
# Germany
# and
# the
# British
# Empire,
# with
# fighting
# in
# the
# Balkans,
# Mediterranean,
# and
# Middle
# East,
# the
# aerial
# Battle
# of
# Britain
# and
# the
# Blitz,
# and
# naval
# Battle
# of
# the
# Atlantic.
# Through
# campaigns
# and
# treaties,
# Germany
# gained
# control
# of
# much
# of
# continental
# Europe
# and
# formed
# the
# Axis
# alliance
# with
# Italy,
# Japan,
# and
# other
# countries.
# In
# June
# 1941,
# Germany
# led
# an
# invasion
# of
# the
# Soviet
# Union,
# opening
# the
# Eastern
# Front
# and
# initially
# making
# large
# territorial
# gains.
# In
# December
# 1941,
# Japan
# attacked
# American
# and
# British
# territories
# in
# Asia
# and
# the
# Pacific,
# including
# at
# Pearl
# Harbor
# in
# Hawaii,
# leading
# the
# United
# States
# to
# enter
# the
# war
# against
# Japan
# and
# Germany.
# Japan
# conquered
# much
# of
# coastal
# China
# and
# Southeast
# Asia,
# but
# its
# advances
# in
# the
# Pacific
# were
# halted
# in
# June
# 1942
# at
# the
# Battle
# of
# Midway.
# In
# late
# 1942,
# Axis
# forces
# were
# defeated
# in
# North
# Africa
# and
# at
# Stalingrad
# in
# the
# Soviet
# Union,
# and
# in
# 1943
# their
# continued
# defeats
# on
# the
# Eastern
# Front,
# an
# Allied
# invasion
# of
# Italy,
# and
# Allied
# offensives
# in
# the
# Pacific
# forced
# them
# into
# retreat
# on
# all
# fronts.
# In
# 1944,
# the
# Western
# Allies
# invaded
# France
# at
# Normandy
# as
# the
# Soviet
# Union
# recaptured
# its
# pre-war
# territory
# and
# the
# U.S.
# crippled
# Japan's
# navy
# and
# captured
# key
# Pacific
# islands.
# The
# war
# in
# Europe
# concluded
# with
# the
# liberation
# of
# German-occupied
# territories;
# invasions
# of
# Germany
# by
# the
# Western
# Allies
# and
# the
# Soviet
# Union,
# which
# culminated
# in
# the
# fall
# of
# Berlin
# to
# Soviet
# troops;
# and
# Germany's
# unconditional
# surrender
# on
# 8
# May
# 1945.
# On
# 6
# and
# 9
# August,
# the
# U.S.
# dropped
# atomic
# bombs
# on
# Hiroshima
# and
# Nagasaki
# in
# Japan.
# Faced
# with
# an
# imminent
# Allied
# invasion,
# the
# prospect
# of
# further
# atomic
# bombings,
# and
# a
# Soviet
# declaration
# of
# war
# and
# invasion
# of
# Manchuria,
# Japan
# announced
# its
# unconditional
# surrender
# on
# 15
# August,
# and
# signed
# a
# surrender
# document
# on
# 2
# September
# 1945.
# World
# War
# II
# transformed
# the
# political,
# economic,
# and
# social
# structures
# of
# the
# world,
# and
# established
# the
# foundation
# of
# international
# relations
# for
# the
# rest
# of
# the
# 20th
# century
# and
# into
# the
# 21st
# century.
# The
# United
# Nations
# was
# created
# to
# foster
# international
# cooperation
# and
# prevent
# future
# conflicts,
# with
# the
# victorious
# great
# powers—China,
# France,
# the
# Soviet
# Union,
# the
# UK,
# and
# the
# U.S.—becoming
# the
# permanent
# members
# of
# its
# security
# council.
# The
# Soviet
# Union
# and
# U.S.
# emerged
# as
# rival
# global
# superpowers,
# setting
# the
# stage
# for
# the
# half-century
# Cold
# War.
# In
# the
# wake
# of
# Europe's
# devastation,
# the
# influence
# of
# its
# great
# powers
# waned,
# triggering
# the
# decolonisation
# of
# Africa
# and
# Asia.
# Many
# countries
# whose
# industries
# had
# been
# damaged
# moved
# towards
# economic
# recovery
# and
# expansion.

# %%
sent_score
# Out:
# {'World War II or the Second World War (1 September 1939 – 2 September 1945) was a global conflict between two coalitions: the Allies and the Axis powers.': 0.4,
#  "Nearly all of the world's countries participated, with many nations mobilising all resources in pursuit of total war.": 0.44999999999999996,
#  'Tanks and aircraft played major roles, enabling the strategic bombing of cities and delivery of the first and only nuclear weapons ever used in war.': 0.49999999999999994,
#  'World War II was the deadliest conflict in history, resulting in 70 to 85 million deaths, more than half of which were civilians.': 0.44999999999999996,
#  'Millions died in genocides, including the Holocaust, and by massacres, starvation, and disease.': 0.15000000000000002,
#  'After the Allied victory, Germany, Austria, Japan, and Korea were occupied, and German and Japanese leaders were tried for war crimes.\n\n': 1.1,
#  'The causes of World War II included unresolved tensions in the aftermath of World War I and the rises of fascism in Europe and militarism in Japan.': 0.44999999999999996,
#  "Key events preceding the war included Japan's invasion of Manchuria in 1931, the Spanish Civil War, the outbreak of the Second Sino-Japanese War in 1937, and Germany's annexations of Austria and the Sudetenland.": 1.5500000000000003,
#  'World War II is generally considered to have begun on 1 September 1939, when Nazi Germany, under Adolf Hitler, invaded Poland, leading the United Kingdom and France to declare war on Germany.': 1.5,
#  'Poland was divided between Germany and the Soviet Union under the Molotov–Ribbentrop Pact.': 0.05,
#  'In 1940, the Soviets annexed the Baltic states and parts of Finland and Romania.': 0.2,
#  'After the fall of France in June 1940, the war continued mainly between Germany and the British Empire, with fighting in the Balkans, Mediterranean, and Middle East, the aerial Battle of Britain and the Blitz, and naval Battle of the Atlantic.': 1.4000000000000004,
#  'Through campaigns and treaties, Germany gained control of much of continental Europe and formed the Axis alliance with Italy, Japan, and other countries.': 0.3,
#  'In June 1941, Germany led an invasion of the Soviet Union, opening the Eastern Front and initially making large territorial gains.\n\n': 0.5499999999999999,
#  'In December 1941, Japan attacked American and British territories in Asia and the Pacific, including at Pearl Harbor in Hawaii, leading the United States to enter the war against Japan and Germany.': 1.4,
#  'Japan conquered much of coastal China and Southeast Asia, but its advances in the Pacific were halted in June 1942 at the Battle of Midway.': 0.30000000000000004,
#  'In late 1942, Axis forces were defeated in North Africa and at Stalingrad in the Soviet Union, and in 1943 their continued defeats on the Eastern Front, an Allied invasion of Italy, and Allied offensives in the Pacific forced them into retreat on all fronts.': 0.7500000000000002,
#  "In 1944, the Western Allies invaded France at Normandy as the Soviet Union recaptured its pre-war territory and the U.S. crippled Japan's navy and captured key Pacific islands.": 0.44999999999999996,
#  "The war in Europe concluded with the liberation of German-occupied territories; invasions of Germany by the Western Allies and the Soviet Union, which culminated in the fall of Berlin to Soviet troops; and Germany's unconditional surrender on 8 May 1945.": 1.6000000000000003,
#  'On 6 and 9 August, the U.S. dropped atomic bombs on Hiroshima and Nagasaki in Japan.': 0.3,
#  'Faced with an imminent Allied invasion, the prospect of further atomic bombings, and a Soviet declaration of war and invasion of Manchuria, Japan announced its unconditional surrender on 15 August, and signed a surrender document on 2 September 1945.\n\n': 2.2,
#  'World War II transformed the political, economic, and social structures of the world, and established the foundation of international relations for the rest of the 20th century and into the 21st century.': 0.7,
#  'The United Nations was created to foster international cooperation and prevent future conflicts, with the victorious great powers—China, France, the Soviet Union, the UK, and the U.S.—becoming the permanent members of its security council.': 0.6500000000000001,
#  'The Soviet Union and U.S. emerged as rival global superpowers, setting the stage for the half-century Cold War.': 0.3,
#  "In the wake of Europe's devastation, the influence of its great powers waned, triggering the decolonisation of Africa and Asia.": 0.44999999999999996,
#  'Many countries whose industries had been damaged moved towards economic recovery and expansion.': 0.45}

# %%
import pandas as pd

# %%
pd.DataFrame(list(sent_score.items()),columns=['Sentence','Score'])
# Out:
#                                              Sentence  Score
# 0   World War II or the Second World War (1 Septem...   0.40
# 1   Nearly all of the world's countries participat...   0.45
# 2   Tanks and aircraft played major roles, enablin...   0.50
# 3   World War II was the deadliest conflict in his...   0.45
# 4   Millions died in genocides, including the Holo...   0.15
# 5   After the Allied victory, Germany, Austria, Ja...   1.10
# 6   The causes of World War II included unresolved...   0.45
# 7   Key events preceding the war included Japan's ...   1.55
# 8   World War II is generally considered to have b...   1.50
# 9   Poland was divided between Germany and the Sov...   0.05
# 10  In 1940, the Soviets annexed the Baltic states...   0.20
# 11  After the fall of France in June 1940, the war...   1.40
# 12  Through campaigns and treaties, Germany gained...   0.30
# 13  In June 1941, Germany led an invasion of the S...   0.55
# 14  In December 1941, Japan attacked American and ...   1.40
# 15  Japan conquered much of coastal China and Sout...   0.30
# 16  In late 1942, Axis forces were defeated in Nor...   0.75
# 17  In 1944, the Western Allies invaded France at ...   0.45
# 18  The war in Europe concluded with the liberatio...   1.60
# 19  On 6 and 9 August, the U.S. dropped atomic bom...   0.30
# 20  Faced with an imminent Allied invasion, the pr...   2.20
# 21  World War II transformed the political, econom...   0.70
# 22  The United Nations was created to foster inter...   0.65
# 23  The Soviet Union and U.S. emerged as rival glo...   0.30
# 24  In the wake of Europe's devastation, the influ...   0.45
# 25  Many countries whose industries had been damag...   0.45

# %%
from heapq import nlargest

# %%
num_sentences =3
n = nlargest(num_sentences,sent_score,key=sent_score.get)

# %%
" ".join(n)
# Out:
# "Faced with an imminent Allied invasion, the prospect of further atomic bombings, and a Soviet declaration of war and invasion of Manchuria, Japan announced its unconditional surrender on 15 August, and signed a surrender document on 2 September 1945.\n\n The war in Europe concluded with the liberation of German-occupied territories; invasions of Germany by the Western Allies and the Soviet Union, which culminated in the fall of Berlin to Soviet troops; and Germany's unconditional surrender on 8 May 1945. Key events preceding the war included Japan's invasion of Manchuria in 1931, the Spanish Civil War, the outbreak of the Second Sino-Japanese War in 1937, and Germany's annexations of Austria and the Sudetenland."

# %%
from transformers import pipeline

# %%
summarizer=pipeline("summarization",model='t5-base',tokenizer='t5-base',framework='pt')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Device set to use cpu

# %%
text = """Each year, stores wait in anticipation to see which titles will emerge as must-haves on the big day — the kinds of drops that bring long lines of fans waiting outside participating stores. With a limited supply for most titles, it can mean fans shuffle from store-to-store seeking their sought-after title. But while searching for those titles, it can also mean finding an unexpected treasure.

“The whole energy in a record store is just super inspiring,” 2025’s Record Store Day Ambassador Post Malone said in a statement provided by the RSD organization in announcing the event. “I feel at home. It’s really an unexplainable feeling to hit up a shop and dig through crates, just see what grabs your eye.”

Malone will issue his Post Malone Tribute to Nirvana, a 2020 livestream performance of Nirvana covers accompanied by blink-182’s Travis Barker on drums, guitarist Nick Mack and bassist Brian Lee. Moreover, 100% of net proceeds from the release will be donated to MusiCares’ Addiction Recovery/Mental Health division.

Malone will also be participating in another RSD release, which is also expected to be a hot item as its a collaboration with 2022’s Record Store Day Ambassador, who also happens to be the biggest music artist in the world, Taylor Swift. They will release their collaboration track “Fortnight,” on a double sided 7-inch vinyl single.

While RSD brings out plenty of long-time collectors, i.e. older demographics, it was Swift who helped spread the day’s popularity to younger fans in 2023 when she caused traffic jams at stores filled with fans seeking her special release of folklore, the long pond studio sessions — a double LP that year. Last year, keeping the young flowing to record stores included releases from Olivia Rodrigo, Noah Kahan, Chappell Roan and Sabrina Carpenter.

This year’s titles for younger music fans include: Gracie Abrams: Live from Radio City Music Hall; Beabadoobee’s Live and Acoustic in London; Megan Thee Stallion’s Traumazine on double black vinyl; and two releases from Charli XCX, the first a collaboration title, Guess featuring Billie Eilish, on 7-inch vinyl; and an edited version of prior release: Number 1 Angel, on apple-colored vinyl with a new RSD exclusive cover. That title’s tracks were previously part of a double-LP release Pop 2.

Moreover, RSD continues to diversify its genres offerings as rap and hip-hop fans will be able to seek titles from Cypress Hill, Anderson .Paak, Snoop Dog and a new release from the Wu-Tang Clan in a collaboration with Mathematics as they release Black Samson, The Bastard Swordsman: Wu-Tang, The Saga Continues Collection on 180-gram LP vinyl. What’s more Wu-Tang Clan are expected to make an appearance at the RSD press event today.

Jazz releases include music from Pharaoh Sanders, Thelonious Monk, Charles Mingus, Gerry Mulligan, and the Vince Guaraldi Trio; while Harry Potter fans will be treated to five different soundtrack albums from that movie series, all on double-LP, clear vinyl.

Finally, in a move to revive another marketing tool previously used to promote RSD, this year’s event will feature a “Record Store Day Song of the Year,” with the tag being applied to the double-a-sided 12-inch single of “Be Here Now,” done by the song’s author George Harrison on one side, with Beck’s cover tribute on the other side.

Other new RSD titles expected to be popular this year include a 12-inch EP collaboration between the Killers and Bruce Springsteen; a David Bowie live-stream from 2003 will now be available as a vinyl and CD release; and a 12-inch, 180-gram yellow vinyl release of John & Yoko with the Plastic Ono Band of their live 1972 One-To-One concert."""

# %%
summary = summarizer(text,max_length=100,min_length=10,do_sample=False)

# %%
summary
# Out:
# [{'summary_text': 'world war II or the Second World War (1 September 1939 – 2 September 1945) was a global conflict between the Allies and the Axis powers . tanks and aircraft played major roles, enabling the strategic bombing of cities and delivery of the first and only nuclear weapons ever used in war . the war transformed the political, economic, and social structures of the world .'}]

# %%
print(summary[0]['summary_text'])
# Out:
# world war II or the Second World War (1 September 1939 – 2 September 1945) was a global conflict between the Allies and the Axis powers . tanks and aircraft played major roles, enabling the strategic bombing of cities and delivery of the first and only nuclear weapons ever used in war . the war transformed the political, economic, and social structures of the world .

# %%
# !pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (4.67.1)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=3bc5465fd87fd667f1142553af22649ac37229a30d443a46af1cb2fdac8f72cf
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
from rouge_score import rouge_scorer

# Define reference summary (human-written)
reference_summary = """World War II, also known as Second World War, is a global conflict fought between the Allies and Axis powers from 1939 to 1945, resulting in as many as 85 million fatalities. It concluded with Germany’s defeat in May 1945 and Japan’s in September following atomic bombings. The war transformed global politics, giving rise to the Cold War and the United Nations."""

# Define generated summary (from your summarization model)
generated_summary = """world war II or the Second World War (1 September 1939 – 2 September 1945) was a global conflict between the Allies and the Axis powers . tanks and aircraft played major roles, enabling the strategic bombing of cities and delivery of the first and only nuclear weapons ever used in war . the war transformed the political, economic, and social structures of the world ."""

# Initialize ROUGE scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# Calculate ROUGE scores
scores = scorer.score(reference_summary, generated_summary)

# Print ROUGE Scores
print("ROUGE-1 Score:", scores['rouge1'])
print("ROUGE-2 Score:", scores['rouge2'])
print("ROUGE-L Score:", scores['rougeL'])
# Out:
# ROUGE-1 Score: Score(precision=0.46774193548387094, recall=0.453125, fmeasure=0.4603174603174603)
# ROUGE-2 Score: Score(precision=0.21311475409836064, recall=0.20634920634920634, fmeasure=0.20967741935483872)
# ROUGE-L Score: Score(precision=0.3709677419354839, recall=0.359375, fmeasure=0.3650793650793651)
